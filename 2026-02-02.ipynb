# %%
import os

# %%
print('hello bhaiya ')
# Out:
# hello bhaiya

# %%
print("isha")
print('axchcha jeet')
# Out:
# isha
# axchcha jeet

# %%
print('isha\naxchcha jeet\n',end='')
# Out:
# isha
# axchcha jeet

# %%
print('j\ne\ne\nt')
# Out:
# j
# e
# e
# t

# %%
for i in [3,4,'5,|ravi bhaiya','jeet|sawasiya',3,2,7]:
    print(i,end= '\n')
# Out:
# 3
# 4
# 5,|ravi bhaiya
# jeet|sawasiya
# 3
# 2
# 7

# %%
for i in range(-5,6):
    print(i,end='')
# Out:
# -5-4-3-2-1012345

# %%
[3,4,5,'jeet',3,2,7]
# Out:
# [3, 4, 5, 'jeet', 3, 2, 7]

# %%
x = int(input())
y = int(input())
z = int(input())
n = int(input())

result = [[i, j, k] 
          for i in range(x + 1) 
          for j in range(y + 1) 
          for k in range(z + 1) 
          if i + j + k != n]

print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x = int(input())
#       2 y = int(input())
#       3 z = int(input())
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a=int(input())
b=int(input())
c='a+b'
d='a-b' 
e=a*b
f=a/b
print('c')
print('b')
print('e')
print('f')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a=int(input())
#       2 b=int(input())
#       3 c='a+b'
#
# ValueError: invalid literal for int() with base 10: ''
